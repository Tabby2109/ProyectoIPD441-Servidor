# %%
# !pip install google-colab-selenium
# Out:
# Collecting google-colab-selenium
#   Downloading google_colab_selenium-1.0.15-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: notebook>=6.5.7 in /usr/local/lib/python3.11/dist-packages (from google-colab-selenium) (6.5.7)
# Collecting selenium (from google-colab-selenium)
#   Downloading selenium-4.34.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (25.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (5.8.1)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.5.7->google-colab-selenium) (1.3.1)
# Requirement already satisfied: urllib3~=2.4.0 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium->google-colab-selenium) (2.4.0)
# Collecting trio~=0.30.0 (from selenium->google-colab-selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium->google-colab-selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.4.26 in /usr/local/lib/python3.11/dist-packages (from selenium->google-colab-selenium) (2025.6.15)
# Requirement already satisfied: typing_extensions~=4.14.0 in /usr/local/lib/python3.11/dist-packages (from selenium->google-colab-selenium) (4.14.0)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium->google-colab-selenium) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-client<8,>=5.3.4->notebook>=6.5.7->google-colab-selenium) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.1->notebook>=6.5.7->google-colab-selenium) (4.3.8)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=6.5.7->google-colab-selenium) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (0.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (2.19.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=6.5.7->google-colab-selenium) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=6.5.7->google-colab-selenium) (4.24.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook>=6.5.7->google-colab-selenium) (0.7.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium->google-colab-selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium->google-colab-selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium->google-colab-selenium) (3.10)
# Collecting outcome (from trio~=0.30.0->selenium->google-colab-selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium->google-colab-selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium->google-colab-selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium->google-colab-selenium) (1.7.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=6.5.7->google-colab-selenium) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook>=6.5.7->google-colab-selenium) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook>=6.5.7->google-colab-selenium) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook>=6.5.7->google-colab-selenium) (0.1.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook>=6.5.7->google-colab-selenium) (5.9.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (1.4.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5.7->google-colab-selenium) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5.7->google-colab-selenium) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5.7->google-colab-selenium) (0.26.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->google-colab-selenium) (1.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.1->jupyter-client<8,>=5.3.4->notebook>=6.5.7->google-colab-selenium) (1.17.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium->google-colab-selenium) (0.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.5.7->google-colab-selenium) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.5.7->google-colab-selenium) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.5.7->google-colab-selenium) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->google-colab-selenium) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook>=6.5.7->google-colab-selenium) (0.2.13)
# Downloading google_colab_selenium-1.0.15-py3-none-any.whl (8.3 kB)
# Downloading selenium-4.34.0-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 97.6 MB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 39.7 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 81.9 MB/s eta 0:00:00
# Installing collected packages: wsproto, outcome, jedi, trio, trio-websocket, selenium, google-colab-selenium
# Successfully installed google-colab-selenium-1.0.15 jedi-0.19.2 outcome-1.3.0.post0 selenium-4.34.0 trio-0.30.0 trio-websocket-0.12.2 wsproto-1.2.0

# %%
import os
import re
import csv
import json
import time
import random
import requests
import pandas as pd
import zipfile
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from google.colab import files

# ========== CONFIGURACIÓN ========== #
CARPETA_PORTADAS = "portadas"
CSV_FILE = "libros.csv"
LETRA = 'W'

if not os.path.exists(CARPETA_PORTADAS):
    os.makedirs(CARPETA_PORTADAS)

# ========== FUNCIONES ========== #

def guardar_portada(url_imagen, titulo, autor_principal):
    nombre_archivo = f"{titulo} - {autor_principal}"
    nombre_archivo = re.sub(r'[\\/*?:"<>|]', "", nombre_archivo) + ".jpg"
    ruta = os.path.join(CARPETA_PORTADAS, nombre_archivo)
    try:
        respuesta = requests.get(url_imagen, timeout=15)
        if respuesta.status_code == 200:
            with open(ruta, "wb") as f:
                f.write(respuesta.content)
            return ruta
    except Exception as e:
        print(f"❌ Error al descargar imagen: {e}")
    return ""

def guardar_en_csv(fila):
    archivo_existe = os.path.exists(CSV_FILE)
    with open(CSV_FILE, "a", encoding="utf-8-sig", newline="") as f:
        writer = csv.writer(f)
        if not archivo_existe:
            encabezados = ["Título", "Autor/es", "Género/s", "Descripción", "Ruta portada"]
            writer.writerow(encabezados)
        writer.writerow(fila)

def procesar_libro(driver, url_libro):
    try:
        driver.get(url_libro)
        time.sleep(2)
        soup = BeautifulSoup(driver.page_source, "html.parser")

        titulo_tag = soup.select_one("div#title h1")
        titulo = titulo_tag.text.strip() if titulo_tag else "Desconocido"

        autores = []
        bloque_autores = soup.find("div", id="autor")
        if bloque_autores:
            autores = [a.text.strip() for a in bloque_autores.find_all("a")]
        autor_principal = autores[0] if autores else "Desconocido"

        generos = []
        bloque_generos = soup.find("div", id="genero")
        if bloque_generos:
            generos = [a.text.strip() for a in bloque_generos.find_all("a")]

        descripcion = ""
        bloque_desc = soup.find("div", id="sinopsis")
        if bloque_desc:
            texto = bloque_desc.find("div", class_="ali_justi")
            if texto:
                descripcion = texto.get_text(separator=" ").strip()
            else:
                descripcion = bloque_desc.get_text(separator=" ").strip()

        ruta_imagen = ""
        img_tag = soup.select_one("div#cover img")
        if img_tag and img_tag.get("src"):
            url_imagen = img_tag["src"]
            ruta_imagen = guardar_portada(url_imagen, titulo, autor_principal)

        fila = [titulo, ", ".join(autores), ", ".join(generos), descripcion, ruta_imagen]
        guardar_en_csv(fila)
        print(f"✅ Guardado: {titulo}")

    except Exception as e:
        print(f"⚠️ Error procesando libro {url_libro}: {e}")

# ========== INICIO ========== #

import google_colab_selenium as gs

driver = gs.Chrome()
driver.get("https://ww3.lectulandia.com/?loggedout=true")
time.sleep(3)

WebDriverWait(driver, 10).until(lambda d: d.execute_script("return typeof jQuery !== 'undefined';"))

print(f"\n🔤 Procesando letra: {LETRA}")

driver.execute_script(f"""
    window.lectuAutores = null;
    jQuery.post('https://ww3.lectulandia.com/wp-admin/admin-ajax.php', {{
        action: 'PDOTaxonomies',
        letra: '{LETRA}',
        term: 'autor'
    }}, function(data) {{
        window.lectuAutores = data;
    }});
""")

try:
    WebDriverWait(driver, 10).until(lambda d: d.execute_script("return window.lectuAutores !== null"))
    autores_raw = driver.execute_script("return window.lectuAutores;")
    autores_dict = json.loads(autores_raw) if isinstance(autores_raw, str) else autores_raw
    lista_autores = list(autores_dict.values())

except Exception as e:
    print(f"⚠️ No se pudieron obtener autores para letra {LETRA}: {e}")
    driver.quit()
    raise

for nombre_autor in lista_autores:
    url_autor = f"https://ww3.lectulandia.com/autor/{nombre_autor}"
    print(f"✍️ Autor: {nombre_autor}")
    try:
        driver.get(url_autor)
        #time.sleep(2)
        soup_autor = BeautifulSoup(driver.page_source, "html.parser")
        libros = soup_autor.find_all("article", class_="card")

        for libro in libros:
            titulo = libro.find("img", class_="cover")["alt"].strip()
            enlace = libro.find("a", class_="title")["href"].strip()
            url_libro = f"https://ww3.lectulandia.com{enlace}"
            print(f"📚 Libro: {titulo}")
            procesar_libro(driver, url_libro)
            #time.sleep(random.uniform(1.5, 3.0))

    except Exception as e:
        print(f"⚠️ Error con autor {nombre_autor}: {e}")

driver.quit()
print("\n🎉 Scraping finalizado.")

# ========== DESCARGA DE RESULTADOS ========== #

# 📄 Mostrar el CSV
df = pd.read_csv(CSV_FILE)
df.head()

# 💾 Descargar CSV
files.download(CSV_FILE)

# 📦 Comprimir carpeta de portadas
zip_file = "portadas.zip"
with zipfile.ZipFile(zip_file, 'w') as zipf:
    for root, _, files_in_dir in os.walk(CARPETA_PORTADAS):
        for file in files_in_dir:
            zipf.write(os.path.join(root, file))

# ⬇️ Descargar ZIP
files.download(zip_file)
# Out:
#             <div class="spinner-container">
#                 <div class="spinner" id="feff27b8-6c2c-4fe8-bcf4-420de975d4a9-circle"></div>
#                 <div class="spinner-text" id="feff27b8-6c2c-4fe8-bcf4-420de975d4a9-text">Updating and upgrading APT</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="452344fa-b462-415e-a978-f2193c2dc10e-circle"></div>
#                 <div class="spinner-text" id="452344fa-b462-415e-a978-f2193c2dc10e-text">Downloading Google Chrome</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="634f3a3b-0799-4a4f-a0f0-486c7857359e-circle"></div>
#                 <div class="spinner-text" id="634f3a3b-0799-4a4f-a0f0-486c7857359e-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
# 🔤 Procesando letra: W
# ✍️ Autor: w-a-harbinson/
# 📚 Libro: Génesis
# ✅ Guardado: Génesis
# ✍️ Autor: w-ama/
# 📚 Libro: Haz que suceda
# ✅ Guardado: Haz que suceda
# 📚 Libro: Vuela alto
# ✅ Guardado: Vuela alto
# 📚 Libro: Para quien se atreve a soñar
# ✅ Guardado: Para quien se atreve a soñar
# 📚 Libro: Donde todo es posible
# ✅ Guardado: Donde todo es posible
# 📚 Libro: Siempre hay un lugar
# ✅ Guardado: Siempre hay un lugar
# 📚 Libro: Descubre el camino
# ✅ Guardado: Descubre el camino
# 📚 Libro: Pide un deseo
# ✅ Guardado: Pide un deseo
# 📚 Libro: Brilla entre las nubes
# ✅ Guardado: Brilla entre las nubes
# 📚 Libro: Cuenta conmigo
# ✅ Guardado: Cuenta conmigo
# 📚 Libro: Sigue adelante
# ✅ Guardado: Sigue adelante
# 📚 Libro: Elige tu estrella
# ✅ Guardado: Elige tu estrella
# 📚 Libro: Todas para una
# ✅ Guardado: Todas para una
# 📚 Libro: Lo mejor de cada una
# ✅ Guardado: Lo mejor de cada una
# ✍️ Autor: w-b-bartlett/
# 📚 Libro: Los asesinos
# ✅ Guardado: Los asesinos
# ✍️ Autor: w-bernard-carlson/
# 📚 Libro: Tesla: inventor de la era eléctrica
# ✅ Guardado: Tesla: inventor de la era eléctrica
# ✍️ Autor: w-bruce-cameron/
# 📚 Libro: La razón de estar contigo: Un nuevo viaje
# ✅ Guardado: La razón de estar contigo: Un nuevo viaje
# 📚 Libro: La razón de estar contigo
# ✅ Guardado: La razón de estar contigo
# ✍️ Autor: w-c-heinz/
# 📚 Libro: El Profesional
# ✅ Guardado: El Profesional
# ✍️ Autor: w-e-bowman/
# 📚 Libro: Hasta arriba
# ✅ Guardado: Hasta arriba
# ✍️ Autor: w-g-sebald/
# 📚 Libro: Campo Santo
# ✅ Guardado: Campo Santo
# 📚 Libro: Los anillos de Saturno
# ✅ Guardado: Los anillos de Saturno
# 📚 Libro: Los emigrados
# ✅ Guardado: Los emigrados
# 📚 Libro: Vértigo
# ✅ Guardado: Vértigo
# 📚 Libro: Sobre la historia natural de la destrucción
# ✅ Guardado: Sobre la historia natural de la destrucción
# 📚 Libro: Austerlitz
# ✅ Guardado: Austerlitz
# ✍️ Autor: w-h-auden/
# 📚 Libro: Canción de cuna y otros poemas
# ✅ Guardado: Canción de cuna y otros poemas
# 📚 Libro: Gracias, niebla
# ✅ Guardado: Gracias, niebla
# 📚 Libro: El arte de leer: Ensayos literarios
# ✅ Guardado: El arte de leer: Ensayos literarios
# 📚 Libro: Carta de Año Nuevo
# ✅ Guardado: Carta de Año Nuevo
# ✍️ Autor: w-h-pugmire/
# 📚 Libro: El ciclo de Dunwich
# ✅ Guardado: El ciclo de Dunwich
# ✍️ Autor: w-j-maryson/
# 📚 Libro: Los abismos de Lan-Gyt
# ✅ Guardado: Los abismos de Lan-Gyt
# 📚 Libro: Las torres de Romander
# ✅ Guardado: Las torres de Romander
# 📚 Libro: El Señor de las Profundidades
# ✅ Guardado: El Señor de las Profundidades
# ✍️ Autor: w-j-stuart/
# 📚 Libro: El planeta desconocido
# ✅ Guardado: El planeta desconocido
# ✍️ Autor: w-j-wilkins/
# 📚 Libro: Mitología hindú
# ✅ Guardado: Mitología hindú
# ✍️ Autor: w-m-flinders-petrie/
# 📚 Libro: La religión de los antiguos egipcios
# ✅ Guardado: La religión de los antiguos egipcios
# ✍️ Autor: w-macfarlane/
# 📚 Libro: Los hijos del diablo
# ✅ Guardado: Los hijos del diablo
# ✍️ Autor: w-michael-gear/
# 📚 Libro: La herencia
# ✅ Guardado: La herencia
# 📚 Libro: La tribu de la niebla
# ✅ Guardado: La tribu de la niebla
# 📚 Libro: La tribu del silencio
# ✅ Guardado: La tribu del silencio
# 📚 Libro: La tribu del río
# ✅ Guardado: La tribu del río
# 📚 Libro: La tribu del fuego
# ✅ Guardado: La tribu del fuego
# 📚 Libro: La tribu de la Tierra
# ✅ Guardado: La tribu de la Tierra
# 📚 Libro: La tribu de los lagos
# ✅ Guardado: La tribu de los lagos
# 📚 Libro: La tribu del lobo
# ✅ Guardado: La tribu del lobo
# ✍️ Autor: w-montgomery-watt/
# 📚 Libro: Historia de la España islámica
# ✅ Guardado: Historia de la España islámica
# ✍️ Autor: w-r-burnett/
# 📚 Libro: Good-bye, Chicago
# ✅ Guardado: Good-bye, Chicago
# 📚 Libro: Muros de adobe
# ✅ Guardado: Muros de adobe
# 📚 Libro: Romelle
# ✅ Guardado: Romelle
# 📚 Libro: Antología de las mejores novelas policíacas – Vol. VII
# ✅ Guardado: Antología de las mejores novelas policíacas – Vol. VII
# 📚 Libro: El último refugio
# ✅ Guardado: El último refugio
# 📚 Libro: Perseguido
# ✅ Guardado: Perseguido
# 📚 Libro: Vanity Row
# ✅ Guardado: Vanity Row
# 📚 Libro: Nadie vive eternamente
# ✅ Guardado: Nadie vive eternamente
# 📚 Libro: El hombre frio
# ✅ Guardado: El hombre frio
# 📚 Libro: El pequeño César
# ✅ Guardado: El pequeño César
# ✍️ Autor: w-r-eiden/
# 📚 Libro: El susurro de las razas
# ✅ Guardado: El susurro de las razas
# ✍️ Autor: w-s-baring-gould/
# 📚 Libro: Sherlock Holmes de Baker Street
# ✅ Guardado: Sherlock Holmes de Baker Street
# ✍️ Autor: w-sampas/
# 📚 Libro: El secreto del Circo Espacial
# ✅ Guardado: El secreto del Circo Espacial
# ✍️ Autor: w-w-jacobs/
# 📚 Libro: La sombra del asesino
# ✅ Guardado: La sombra del asesino
# 📚 Libro: Cuentos de tatuajes
# ✅ Guardado: Cuentos de tatuajes
# 📚 Libro: TerrorVisión
# ✅ Guardado: TerrorVisión
# 📚 Libro: La pata de mono
# ✅ Guardado: La pata de mono
# ✍️ Autor: wade-miller/
# 📚 Libro: Al sur del Sol
# ✅ Guardado: Al sur del Sol
# 📚 Libro: El arma mortal
# ✅ Guardado: El arma mortal
# 📚 Libro: La elección del asesino
# ✅ Guardado: La elección del asesino
# 📚 Libro: Paso fatal
# ✅ Guardado: Paso fatal
# 📚 Libro: Calle siniestra
# ✅ Guardado: Calle siniestra
# ✍️ Autor: wajdi-mouawad/
# 📚 Libro: Incendios
# ✅ Guardado: Incendios
# 📚 Libro: Ánima
# ✅ Guardado: Ánima
# ✍️ Autor: waldemar-bonsels/
# 📚 Libro: Las aventuras de la abeja Maya
# ✅ Guardado: Las aventuras de la abeja Maya
# ✍️ Autor: wallace-breem/
# 📚 Libro: El águila en la nieve
# ✅ Guardado: El águila en la nieve
# 📚 Libro: El enviado de Roma
# ✅ Guardado: El enviado de Roma
# ✍️ Autor: wallace-reyburn/
# 📚 Libro: Tres mujeres
# ✅ Guardado: Tres mujeres
# ✍️ Autor: wallace-stegner/
# 📚 Libro: En lugar seguro
# ✅ Guardado: En lugar seguro
# 📚 Libro: Ángulo de reposo
# ✅ Guardado: Ángulo de reposo
# 📚 Libro: El pájaro espectador
# ✅ Guardado: El pájaro espectador
# ✍️ Autor: wallace-stevens/
# 📚 Libro: Notas para una ficción suprema
# ✅ Guardado: Notas para una ficción suprema
# 📚 Libro: Domingo a la mañana y otros poemas
# ✅ Guardado: Domingo a la mañana y otros poemas
# ✍️ Autor: walt-whitman/
# 📚 Libro: Hojas de hierba (Ed. bilingüe)
# ✅ Guardado: Hojas de hierba (Ed. bilingüe)
# 📚 Libro: La extensión de mi cuerpo
# ✅ Guardado: La extensión de mi cuerpo
# 📚 Libro: Crímenes de autor
# ✅ Guardado: Crímenes de autor
# 📚 Libro: Canto a mí mismo
# ✅ Guardado: Canto a mí mismo
# 📚 Libro: Franklin Evans, el borracho
# ✅ Guardado: Franklin Evans, el borracho
# 📚 Libro: ¡Oh, Capitán! ¡Mi Capitán!
# ✅ Guardado: ¡Oh, Capitán! ¡Mi Capitán!
# 📚 Libro: La extensión de mi cuerpo (Ilustrado/Bilingüe)
# ✅ Guardado: La extensión de mi cuerpo (Ilustrado/Bilingüe)
# 📚 Libro: Hojas de hierba & Selección de prosas
# ✅ Guardado: Hojas de hierba & Selección de prosas
# 📚 Libro: Hojas de hierba
# ✅ Guardado: Hojas de hierba
# ✍️ Autor: walter-astori/
# 📚 Libro: Asesinato en las afueras
# ✅ Guardado: Asesinato en las afueras
# 📚 Libro: Asesinato en Roma
# ✅ Guardado: Asesinato en Roma
# ✍️ Autor: walter-benjamin/
# 📚 Libro: Historias desde la soledad y otras narraciones
# ✅ Guardado: Historias desde la soledad y otras narraciones
# 📚 Libro: Infancia en Berlín hacia 1900
# ✅ Guardado: Infancia en Berlín hacia 1900
# 📚 Libro: El París de Baudelaire
# ✅ Guardado: El París de Baudelaire
# 📚 Libro: Libro I/Vol. 2
# ✅ Guardado: Libro I/Vol. 2
# 📚 Libro: Brecht: Ensayos y conversaciones
# ✅ Guardado: Brecht: Ensayos y conversaciones
# 📚 Libro: Radio Benjamin
# ✅ Guardado: Radio Benjamin
# 📚 Libro: Desembalo mi biblioteca
# ✅ Guardado: Desembalo mi biblioteca
# 📚 Libro: Discursos interrumpidos I
# ✅ Guardado: Discursos interrumpidos I
# 📚 Libro: El autor como productor
# ✅ Guardado: El autor como productor
# 📚 Libro: Sueños
# ✅ Guardado: Sueños
# 📚 Libro: Calle de sentido único
# ✅ Guardado: Calle de sentido único
# 📚 Libro: Libro IV/Vol. 2
# ✅ Guardado: Libro IV/Vol. 2
# 📚 Libro: Haschisch
# ✅ Guardado: Haschisch
# 📚 Libro: Libro II/Vol. 1
# ✅ Guardado: Libro II/Vol. 1
# 📚 Libro: Libro I/Vol. 1
# ✅ Guardado: Libro I/Vol. 1
# 📚 Libro: Obras Completas Vol. 2
# ✅ Guardado: Obras Completas Vol. 2
# 📚 Libro: Diario de Moscú
# ✅ Guardado: Diario de Moscú
# 📚 Libro: Correspondencia entre Erich Auerbach y Walter Benjamin (1935 – 1937)
# ✅ Guardado: Correspondencia entre Erich Auerbach y Walter Benjamin (1935 – 1937)
# 📚 Libro: La obra de arte en la época de su reproductibilidad técnica
# ✅ Guardado: La obra de arte en la época de su reproductibilidad técnica
# 📚 Libro: Dirección única
# ✅ Guardado: Dirección única
# ✍️ Autor: walter-besant/
# 📚 Libro: Narraciones terroríficas – Vol. 6
# ✅ Guardado: Narraciones terroríficas – Vol. 6
# ✍️ Autor: walter-block/
# 📚 Libro: Defendiendo lo indefendible
# ✅ Guardado: Defendiendo lo indefendible
# ✍️ Autor: walter-bosing/
# 📚 Libro: El Bosco
# ✅ Guardado: El Bosco
# ✍️ Autor: walter-c-debill-jr/
# 📚 Libro: Los Discípulos de Cthulhu
# ✅ Guardado: Los Discípulos de Cthulhu
# ✍️ Autor: walter-carrigan/
# 📚 Libro: La odisea del Kipsedon
# ✅ Guardado: La odisea del Kipsedon
# ✍️ Autor: walter-dresel/
# 📚 Libro: Toma un café contigo mismo
# ✅ Guardado: Toma un café contigo mismo
# 📚 Libro: Yo te manipulo, ¿y tú qué haces?
# ✅ Guardado: Yo te manipulo, ¿y tú qué haces?
# ✍️ Autor: walter-duranty/
# 📚 Libro: Antología de las mejores novelas policíacas – Vol. VII
# ✅ Guardado: Antología de las mejores novelas policíacas – Vol. VII
# ✍️ Autor: walter-ernsting/
# 📚 Libro: Nueva Dimensión 2
# ✅ Guardado: Nueva Dimensión 2
# ✍️ Autor: walter-f-otto/
# 📚 Libro: Los dioses de Grecia
# ✅ Guardado: Los dioses de Grecia
# 📚 Libro: Las Musas
# ✅ Guardado: Las Musas
# 📚 Libro: Dioniso. Mito y culto
# ✅ Guardado: Dioniso. Mito y culto
# ✍️ Autor: walter-gratzer/
# 📚 Libro: Eurekas y euforias
# ✅ Guardado: Eurekas y euforias
# ✍️ Autor: walter-greatshell/
# 📚 Libro: Agente X
# ✅ Guardado: Agente X
# 📚 Libro: Apocalipso
# ✅ Guardado: Apocalipso
# 📚 Libro: Prisioneros
# ✅ Guardado: Prisioneros
# ✍️ Autor: walter-isaacson/
# 📚 Libro: El código de la vida
# ✅ Guardado: El código de la vida
# 📚 Libro: Leonardo da Vinci. La biografía
# ✅ Guardado: Leonardo da Vinci. La biografía
# 📚 Libro: Steve Jobs: Lecciones de liderazgo
# ✅ Guardado: Steve Jobs: Lecciones de liderazgo
# 📚 Libro: Los innovadores
# ✅ Guardado: Los innovadores
# 📚 Libro: Einstein: Su vida y su universo
# ✅ Guardado: Einstein: Su vida y su universo
# 📚 Libro: Steve Jobs
# ✅ Guardado: Steve Jobs
# ✍️ Autor: walter-j-ong/
# 📚 Libro: Oralidad y escritura
# ✅ Guardado: Oralidad y escritura
# ✍️ Autor: walter-jon-williams/
# 📚 Libro: Metropol
# ✅ Guardado: Metropol
# 📚 Libro: Hardwired
# ✅ Guardado: Hardwired
# 📚 Libro: Canallas
# ✅ Guardado: Canallas
# 📚 Libro: Premios Nebula 1987
# ✅ Guardado: Premios Nebula 1987
# 📚 Libro: Los caminos del destino I
# ✅ Guardado: Los caminos del destino I
# 📚 Libro: Los caminos del destino II
# ✅ Guardado: Los caminos del destino II
# 📚 Libro: Hardwired, el hombre-máquina
# ✅ Guardado: Hardwired, el hombre-máquina
# ✍️ Autor: walter-kempley/
# 📚 Libro: Cálculo de probabilidades
# ✅ Guardado: Cálculo de probabilidades
# ✍️ Autor: walter-kempowski/
# 📚 Libro: Todo en vano
# ✅ Guardado: Todo en vano
# ✍️ Autor: walter-kirn/
# 📚 Libro: La sangre no miente
# ✅ Guardado: La sangre no miente
# 📚 Libro: Up in the air
# ✅ Guardado: Up in the air
# ✍️ Autor: walter-lennig/
# 📚 Libro: E.A. Poe
# ✅ Guardado: E.A. Poe
# ✍️ Autor: walter-lewin/
# 📚 Libro: Por amor a la física
# ✅ Guardado: Por amor a la física
# ✍️ Autor: walter-m-miller-jr/
# 📚 Libro: Cuatro pasos al futuro
# ✅ Guardado: Cuatro pasos al futuro
# 📚 Libro: Condicionalmente humano
# ✅ Guardado: Condicionalmente humano
# 📚 Libro: Los premios Hugo 1955-1961
# ✅ Guardado: Los premios Hugo 1955-1961
# 📚 Libro: Cae la noche
# ✅ Guardado: Cae la noche
# 📚 Libro: Ciencia ficción, Selección 39
# ✅ Guardado: Ciencia ficción, Selección 39
# 📚 Libro: Cántico por Leibowitz
# ✅ Guardado: Cántico por Leibowitz
# 📚 Libro: San Leibowitz y la mujer Caballo Salvaje
# ✅ Guardado: San Leibowitz y la mujer Caballo Salvaje
# ✍️ Autor: walter-mischel/
# 📚 Libro: El test de la golosina
# ✅ Guardado: El test de la golosina
# ✍️ Autor: walter-moers/
# 📚 Libro: El maestro de las Burujas
# ✅ Guardado: El maestro de las Burujas
# 📚 Libro: Las 13 vidas y media del Capitán Osoazul
# ✅ Guardado: Las 13 vidas y media del Capitán Osoazul
# 📚 Libro: La ciudad de los libros soñadores
# ✅ Guardado: La ciudad de los libros soñadores
# ✍️ Autor: walter-mosley/
# 📚 Libro: A cuerpo de rey
# ✅ Guardado: A cuerpo de rey
# 📚 Libro: Al rojo vivo
# ✅ Guardado: Al rojo vivo
# 📚 Libro: Matar a Johnny Fry
# ✅ Guardado: Matar a Johnny Fry
# 📚 Libro: Luz azul
# ✅ Guardado: Luz azul
# 📚 Libro: Blues de los sueños rotos
# ✅ Guardado: Blues de los sueños rotos
# 📚 Libro: Siete casos
# ✅ Guardado: Siete casos
# 📚 Libro: Traición
# ✅ Guardado: Traición
# 📚 Libro: Rubia peligrosa
# ✅ Guardado: Rubia peligrosa
# 📚 Libro: Beso canela
# ✅ Guardado: Beso canela
# 📚 Libro: Muerte escarlata
# ✅ Guardado: Muerte escarlata
# 📚 Libro: El caso Brown
# ✅ Guardado: El caso Brown
# 📚 Libro: De pesca
# ✅ Guardado: De pesca
# 📚 Libro: Un perro amarillo
# ✅ Guardado: Un perro amarillo
# 📚 Libro: Betty la negra
# ✅ Guardado: Betty la negra
# 📚 Libro: Mariposa blanca
# ✅ Guardado: Mariposa blanca
# 📚 Libro: Una muerte roja
# ✅ Guardado: Una muerte roja
# 📚 Libro: El demonio vestido de azul
# ✅ Guardado: El demonio vestido de azul
# ✍️ Autor: walter-murch/
# 📚 Libro: En el momento del parpadeo
# ✅ Guardado: En el momento del parpadeo
# ✍️ Autor: walter-pernas/
# 📚 Libro: Comandante Facundo
# ✅ Guardado: Comandante Facundo
# ✍️ Autor: walter-penaloza-ramella/
# 📚 Libro: Cómo Fujimori jodió al Perú
# ✅ Guardado: Cómo Fujimori jodió al Perú
# ✍️ Autor: walter-popp/
# 📚 Libro: La justicia de Selb
# ✅ Guardado: La justicia de Selb
# ✍️ Autor: walter-riso/
# 📚 Libro: Deshojando margaritas
# ✅ Guardado: Deshojando margaritas
# 📚 Libro: Pizzería Vesubio
# ✅ Guardado: Pizzería Vesubio
# 📚 Libro: ¿Amar o depender?
# ✅ Guardado: ¿Amar o depender?
# 📚 Libro: Los límites del amor
# ✅ Guardado: Los límites del amor
# ✍️ Autor: walter-scheidel/
# 📚 Libro: El gran nivelador
# ✅ Guardado: El gran nivelador
# ✍️ Autor: walter-scott/
# 📚 Libro: El talismán
# ✅ Guardado: El talismán
# 📚 Libro: Cuentos sobrenaturales
# ✅ Guardado: Cuentos sobrenaturales
# 📚 Libro: Woodstock
# ✅ Guardado: Woodstock
# 📚 Libro: Ivanhoe (Ilustrado Tus Libros)
# ✅ Guardado: Ivanhoe (Ilustrado Tus Libros)
# 📚 Libro: Ivanhoe (ilustrado)
# ✅ Guardado: Ivanhoe (ilustrado)
# 📚 Libro: El Enano Negro (Ilustrado)
# ✅ Guardado: El Enano Negro (Ilustrado)
# 📚 Libro: El talismán (Ilustrado)
# ✅ Guardado: El talismán (Ilustrado)
# 📚 Libro: Rob Roy
# ✅ Guardado: Rob Roy
# 📚 Libro: El anticuario
# ✅ Guardado: El anticuario
# 📚 Libro: El pirata
# ✅ Guardado: El pirata
# 📚 Libro: Eterna Mortalidad
# ✅ Guardado: Eterna Mortalidad
# 📚 Libro: El Monasterio
# ✅ Guardado: El Monasterio
# 📚 Libro: El horror según Lovecraft (vol I)
# ✅ Guardado: El horror según Lovecraft (vol I)
# 📚 Libro: Cuentos fantásticos del XIX
# ✅ Guardado: Cuentos fantásticos del XIX
# 📚 Libro: Quintín Durward
# ✅ Guardado: Quintín Durward
# 📚 Libro: La novia de Lammermoor
# ✅ Guardado: La novia de Lammermoor
# 📚 Libro: Ivanhoe
# ✅ Guardado: Ivanhoe
# 📚 Libro: Robin Hood
# ✅ Guardado: Robin Hood
# ✍️ Autor: walter-siti/
# 📚 Libro: El contagio
# ✅ Guardado: El contagio
# ✍️ Autor: walter-tevis/
# 📚 Libro: Las huellas del sol
# ✅ Guardado: Las huellas del sol
# 📚 Libro: El color del dinero
# ✅ Guardado: El color del dinero
# 📚 Libro: Sinsonte
# ✅ Guardado: Sinsonte
# 📚 Libro: Gambito de dama
# ✅ Guardado: Gambito de dama
# 📚 Libro: El pájaro burlón
# ✅ Guardado: El pájaro burlón
# 📚 Libro: El hombre que cayó a la Tierra
# ✅ Guardado: El hombre que cayó a la Tierra
# 📚 Libro: El buscavidas
# ✅ Guardado: El buscavidas
# ✍️ Autor: walter-van-tilburg-clark/
# 📚 Libro: Antología de novelas del Oeste Vol. III
# ✅ Guardado: Antología de novelas del Oeste Vol. III
# 📚 Libro: Los mejores relatos de anticipación
# ✅ Guardado: Los mejores relatos de anticipación
# ✍️ Autor: walter-vasquez/
# 📚 Libro: En busca del fin del mundo
# ✅ Guardado: En busca del fin del mundo
# ✍️ Autor: walter-zacharius/
# 📚 Libro: La pianista de Varsovia
# ✅ Guardado: La pianista de Varsovia
# ✍️ Autor: walter-de-la-mare/
# 📚 Libro: Memorias de una enana
# ✅ Guardado: Memorias de una enana
# 📚 Libro: El horror según Lovecraft (vol II)
# ✅ Guardado: El horror según Lovecraft (vol II)
# ✍️ Autor: walter-alexandre-schultz/
# 📚 Libro: 50 supermodelos de papiroflexia
# ✅ Guardado: 50 supermodelos de papiroflexia
# ✍️ Autor: walther-erwes/
# 📚 Libro: Lo mejor de la ciencia ficción alemana
# ✅ Guardado: Lo mejor de la ciencia ficción alemana
# ✍️ Autor: wame-m-molefhe/
# 📚 Libro: Ve, cuéntaselo al sol
# ✅ Guardado: Ve, cuéntaselo al sol
# ✍️ Autor: wanda-marasco/
# 📚 Libro: Un coro de almas
# ✅ Guardado: Un coro de almas
# ✍️ Autor: wang-shuo/
# 📚 Libro: Haz el favor de no llamarme humano
# ✅ Guardado: Haz el favor de no llamarme humano
# ✍️ Autor: ward-hawkins/
# 📚 Libro: Antología de las mejores novelas policíacas – Vol. V
# ✅ Guardado: Antología de las mejores novelas policíacas – Vol. V
# ✍️ Autor: ward-moore/
# 📚 Libro: Antología de novelas de anticipación IV (reedición)
# ✅ Guardado: Antología de novelas de anticipación IV (reedición)
# 📚 Libro: Los mejores relatos de anticipación
# ✅ Guardado: Los mejores relatos de anticipación
# 📚 Libro: Cae la noche
# ✅ Guardado: Cae la noche
# 📚 Libro: Más verde de lo que creéis
# ✅ Guardado: Más verde de lo que creéis
# 📚 Libro: Lo que el tiempo se llevó
# ✅ Guardado: Lo que el tiempo se llevó
# 📚 Libro: Antología de novelas de anticipación IV
# ✅ Guardado: Antología de novelas de anticipación IV
# ✍️ Autor: waris-dirie/
# 📚 Libro: Flor del desierto
# ✅ Guardado: Flor del desierto
# ✍️ Autor: warren-b-smith/
# 📚 Libro: La magia de Krynn
# ✅ Guardado: La magia de Krynn
# ✍️ Autor: warren-ellis/
# 📚 Libro: Ritual de muerte
# ✅ Guardado: Ritual de muerte
# ✍️ Autor: warren-fahy/
# 📚 Libro: Henders
# ✅ Guardado: Henders
# ✍️ Autor: warren-h-schmidt/
# 📚 Libro: Un pavo real en el reino de los pingüinos
# ✅ Guardado: Un pavo real en el reino de los pingüinos
# ✍️ Autor: warren-mosler/
# 📚 Libro: Los siete fraudes inocentes capitales de la política económica
# ✅ Guardado: Los siete fraudes inocentes capitales de la política económica
# ✍️ Autor: warren-murphy/
# 📚 Libro: Los marranos engordan
# ✅ Guardado: Los marranos engordan
# ✍️ Autor: washington-irving/
# 📚 Libro: Vieja Navidad
# ✅ Guardado: Vieja Navidad
# 📚 Libro: La leyenda de Sleepy Hollow y otros relatos
# ✅ Guardado: La leyenda de Sleepy Hollow y otros relatos
# 📚 Libro: Relatos inquietantes para chicos valientes
# ✅ Guardado: Relatos inquietantes para chicos valientes
# 📚 Libro: Antología de novelas del Oeste Vol. VIII
# ✅ Guardado: Antología de novelas del Oeste Vol. VIII
# 📚 Libro: Cuentos de la Alhambra (Ed. Miguel Sánchez)
# ✅ Guardado: Cuentos de la Alhambra (Ed. Miguel Sánchez)
# 📚 Libro: Cuentos de la Alhambra (Ed. Susaeta)
# ✅ Guardado: Cuentos de la Alhambra (Ed. Susaeta)
# 📚 Libro: Miedo en el cuerpo
# ✅ Guardado: Miedo en el cuerpo
# 📚 Libro: Siete relatos góticos: del papel a la pantalla
# ✅ Guardado: Siete relatos góticos: del papel a la pantalla
# 📚 Libro: Una historia de Nueva York
# ✅ Guardado: Una historia de Nueva York
# 📚 Libro: Rip van Winkle (Ilustrado)
# ✅ Guardado: Rip van Winkle (Ilustrado)
# 📚 Libro: Historias cómicas de fantasmas
# ✅ Guardado: Historias cómicas de fantasmas
# 📚 Libro: Narraciones terroríficas – Vol. 1
# ✅ Guardado: Narraciones terroríficas – Vol. 1
# 📚 Libro: La leyenda del jinete sin cabeza
# ✅ Guardado: La leyenda del jinete sin cabeza
# 📚 Libro: Relatos del mar
# ✅ Guardado: Relatos del mar
# 📚 Libro: Los buscadores de tesoros
# ✅ Guardado: Los buscadores de tesoros
# 📚 Libro: Antología del cuento norteamericano
# ✅ Guardado: Antología del cuento norteamericano
# 📚 Libro: La leyenda de Sleepy Hollow y otros cuentos de fantasmas
# ✅ Guardado: La leyenda de Sleepy Hollow y otros cuentos de fantasmas
# 📚 Libro: La leyenda de Sleepy Hollow
# ✅ Guardado: La leyenda de Sleepy Hollow
# 📚 Libro: Cuentos de la Alhambra
# ✅ Guardado: Cuentos de la Alhambra
# ✍️ Autor: wassily-kandinsky/
# 📚 Libro: De lo espiritual en el arte
# ✅ Guardado: De lo espiritual en el arte
# ✍️ Autor: wassyla-tamzali/
# 📚 Libro: Carta de una mujer indignada desde el Magreb a Europa
# ✅ Guardado: Carta de una mujer indignada desde el Magreb a Europa
# ✍️ Autor: wayland-drew/
# 📚 Libro: Willow
